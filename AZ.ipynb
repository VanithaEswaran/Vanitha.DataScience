# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_az=pd.read_csv("C:/Users/nates/Desktop/Vanitha/ProjectDS/alzheimer_s_disease_and_healthy_aging_data.csv")

# %%
df_az.head()
# Out:
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 0    BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022           PA
# 1    BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022           SD
# 2    BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022           ID
# 3    BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022           MD
# 4  BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022           WI
#
#    LocationDesc Datasource          Class                     Topic  \
# 0  Pennsylvania      BRFSS  Mental Health  Frequent mental distress
# 1  South Dakota      BRFSS  Mental Health  Frequent mental distress
# 2         Idaho      BRFSS  Mental Health  Frequent mental distress
# 3      Maryland      BRFSS  Mental Health  Frequent mental distress
# 4     Wisconsin      BRFSS  Mental Health  Frequent mental distress
#
#                                             Question Data_Value_Unit  ...  \
# ...

# %%
df_az.drop('RowId',axis=1,inplace=True)

# %%
df_az.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc Datasource          Class  \
# 0       2022     2022           PA  Pennsylvania      BRFSS  Mental Health
# 1       2022     2022           SD  South Dakota      BRFSS  Mental Health
# 2       2022     2022           ID         Idaho      BRFSS  Mental Health
# 3       2022     2022           MD      Maryland      BRFSS  Mental Health
# 4       2022     2022           WI     Wisconsin      BRFSS  Mental Health
#
#                       Topic  \
# 0  Frequent mental distress
# 1  Frequent mental distress
# 2  Frequent mental distress
# 3  Frequent mental distress
# 4  Frequent mental distress
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults who are experiencin...               %
# 1  Percentage of older adults who are experiencin...               %
# 2  Percentage of older adults who are experiencin...               %
# ...

# %%
df_az['RowId']=df_az.index

# %%
df_az.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc Datasource          Class  \
# 0       2022     2022           PA  Pennsylvania      BRFSS  Mental Health
# 1       2022     2022           SD  South Dakota      BRFSS  Mental Health
# 2       2022     2022           ID         Idaho      BRFSS  Mental Health
# 3       2022     2022           MD      Maryland      BRFSS  Mental Health
# 4       2022     2022           WI     Wisconsin      BRFSS  Mental Health
#
#                       Topic  \
# 0  Frequent mental distress
# 1  Frequent mental distress
# 2  Frequent mental distress
# 3  Frequent mental distress
# 4  Frequent mental distress
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults who are experiencin...               %
# 1  Percentage of older adults who are experiencin...               %
# 2  Percentage of older adults who are experiencin...               %
# ...

# %%
df_az.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'DataValueTypeID',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2', 'RowId'],
#       dtype='object')

# %%
df_az.drop(['Data_Value_Unit','DataValueTypeID','Data_Value_Type'],axis=1,inplace=True)

# %%
# Dropping off all the repeating columns

# %%
df_az.drop(['StratificationCategory1','StratificationCategory2','StratificationCategoryID1', 'StratificationID1',
       'StratificationCategoryID2', 'StratificationID2'],axis=1,inplace=True)

# %%
df_az.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Stratification1',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'RowId'],
#       dtype='object')

# %%
# renaming the columns as per the data it contains

# %%
df_az.rename(columns={'Stratification1':'Age_Group','Stratification2':'Race_Ethnicity_Gender'},inplace=True)

# %%
df_az.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Age_Group',
#        'Race_Ethnicity_Gender', 'Geolocation', 'ClassID', 'TopicID',
#        'QuestionID', 'LocationID', 'RowId'],
#       dtype='object')

# %%
df_az['Race_Ethnicity']=df_az[~df_az.Race_Ethnicity_Gender.isin(['Male','Female'])]['Race_Ethnicity_Gender']

# %%
df_az['Gender']=df_az[df_az.Race_Ethnicity_Gender.isin(['Male','Female'])]['Race_Ethnicity_Gender']

# %%
df_az.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc Datasource          Class  \
# 0       2022     2022           PA  Pennsylvania      BRFSS  Mental Health
# 1       2022     2022           SD  South Dakota      BRFSS  Mental Health
# 2       2022     2022           ID         Idaho      BRFSS  Mental Health
# 3       2022     2022           MD      Maryland      BRFSS  Mental Health
# 4       2022     2022           WI     Wisconsin      BRFSS  Mental Health
#
#                       Topic  \
# 0  Frequent mental distress
# 1  Frequent mental distress
# 2  Frequent mental distress
# 3  Frequent mental distress
# 4  Frequent mental distress
#
#                                             Question  Data_Value  \
# 0  Percentage of older adults who are experiencin...         NaN
# 1  Percentage of older adults who are experiencin...         NaN
# 2  Percentage of older adults who are experiencin...         NaN
# 3  Percentage of older adults who are experiencin...         9.0
# ...

# %%
def gender_predict(str2):
    str1='male-Female'
    if 'Men' in str2:
        return 'Male'
    if 'Women' in str2:
        return 'Female'
    else:
        return 'UnKnown'

# %%
print(gender_predict("Up-to-date with recommended vaccines and screenings - Women"))
# Out:
# Female

# %%
df_az['Gender'].unique()
# Out:
# array([nan, 'Male', 'Female'], dtype=object)

# %%
df=df_az[0:5]

# %%
# Gender data filled based on the Topic or Question

# %%
df_az['Gender']=df_az.apply(lambda row:gender_predict(row['Topic']) if pd.isnull(row['Gender']) else row['Gender'],axis=1)

# %%
df_az['Gender']=df_az.apply(lambda row:gender_predict(row['Question']) if pd.isnull(row['Gender']) else row['Gender'],axis=1)

# %%
df_az.head()

# %%
df_az[['Topic','Gender']].head(10)
# Out:
#                                                Topic   Gender
# 0                           Frequent mental distress  UnKnown
# 1                           Frequent mental distress  UnKnown
# 2                           Frequent mental distress  UnKnown
# 3                           Frequent mental distress  UnKnown
# 4                           Frequent mental distress     Male
# 5                           Frequent mental distress  UnKnown
# 6                           Frequent mental distress  UnKnown
# 7                           Frequent mental distress  UnKnown
# 8  Disability status, including sensory or mobili...   Female
# 9  Disability status, including sensory or mobili...  UnKnown

# %%
df_az['Gender'].isnull().sum()
# Out:
# 215304

# %%
df_az['Gender'].isnull().sum()
# Out:
# 0

# %%
df_az['Gender'].isin(['None']).sum()
# Out:
# 207004

# %%
df_az.shape
# Out:
# (284142, 25)

# %%
df_az['Gender'].count()
# Out:
# 284142

# %%
df_az.isnull().sum()
# Out:
# YearStart                          0
# YearEnd                            0
# LocationAbbr                       0
# LocationDesc                       0
# Datasource                         0
# Class                              0
# Topic                              0
# Question                           0
# Data_Value                     91334
# Data_Value_Alt                 91334
# Data_Value_Footnote_Symbol    174166
# Data_Value_Footnote           174166
# Low_Confidence_Limit           91545
# High_Confidence_Limit          91545
# Age_Group                          0
# Race_Ethnicity_Gender          36873
# Geolocation                    30489
# ClassID                            0
# TopicID                            0
# QuestionID                         0
# LocationID                         0
# RowId                              0
# Race_Ethnicity                105711
# Gender                             0
# dtype: int64

# %%
df_az['ClassID'].unique()
# Out:
# array(['C05', 'C01', 'C03', 'C02', 'C04', 'C06', 'C07'], dtype=object)

# %%
df_az['Age_Group'].unique()
# Out:
# array(['50-64 years', '65 years or older', 'Overall'], dtype=object)

# %%
df_az['Question'].unique()
# Out:
# array(['Percentage of older adults who are experiencing frequent mental distress',
#        'Percentage of older adults who report having a disability (includes limitations related to sensory or mobility impairments or a physical, mental, or emotional condition)',
#        'Percentage of older adults who report having lost 5 or fewer teeth due to decay or gum disease',
#        'Percentage of at risk adults (have diabetes, asthma, cardiovascular disease or currently smoke) who ever had a pneumococcal vaccine',
#        'Percentage of older adult men who are up to date with select clinical preventive services',
#        'Percentage of older adult women who are up to date with select clinical preventive services',
#        'Percentage of older adult women who have received a mammogram within the past 2 years',
#        'Percentage of older adult women with an intact cervix who had a Pap test within the past 3 years',
# ...

# %%
df_az['Gender'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df_az.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284142 entries, 0 to 284141
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   YearStart                   284142 non-null  int64
#  1   YearEnd                     284142 non-null  int64
#  2   LocationAbbr                284142 non-null  object
#  3   LocationDesc                284142 non-null  object
#  4   Datasource                  284142 non-null  object
#  5   Class                       284142 non-null  object
#  6   Topic                       284142 non-null  object
#  7   Question                    284142 non-null  object
#  8   Data_Value                  192808 non-null  float64
#  9   Data_Value_Alt              192808 non-null  float64
#  10  Data_Value_Footnote_Symbol  109976 non-null  object
#  11  Data_Value_Footnote         109976 non-null  object
# ...

# %%
df_az.drop(['Data_Value_Alt','Data_Value_Footnote_Symbol'],axis=1,inplace=True)

# %%
# count plot on Age Group
sns.countplot(x ='Age_Group', data = df_az,hue='Age_Group')
 
# Show the plot
plt.show()

# %%
df_az['Race_Ethnicity'].fillna('UnKnown',inplace=True)

# %%
df_az['Race_Ethnicity'].unique()
# Out:
# array(['Native Am/Alaskan Native', 'Asian/Pacific Islander',
#        'Black, non-Hispanic', 'UnKnown', 'White, non-Hispanic',
#        'Hispanic'], dtype=object)

# %%
# count plot on Age Group
fig = plt.figure(figsize = (15, 5))
sns.countplot(x ='Race_Ethnicity', data = df_az[df_az.Race_Ethnicity!='UnKnown'])
 
# Show the plot
plt.show()

# %%
df_az['Class'].unique()
# Out:
# array(['Mental Health', 'Overall Health', 'Screenings and Vaccines',
#        'Nutrition/Physical Activity/Obesity', 'Smoking and Alcohol Use',
#        'Cognitive Decline', 'Caregiving'], dtype=object)

# %%
#Distribution of percentage of data among Race_Ethnicity

# %%
df_az_Race_Ethnicity=df_az[['Race_Ethnicity','Data_Value']].groupby('Race_Ethnicity').mean().reset_index()

# %%
df_az_Race_Ethnicity
# Out:
#              Race_Ethnicity  Data_Value
# 0    Asian/Pacific Islander   38.334273
# 1       Black, non-Hispanic   40.395094
# 2                  Hispanic   39.993057
# 3  Native Am/Alaskan Native   42.961210
# 4                   UnKnown   36.515322
# 5       White, non-Hispanic   36.979716

# %%
sns.displot(df_az[df_az.Race_Ethnicity!='UnKnown'], x="Data_Value", hue="Race_Ethnicity", kind="kde")

# %%
# count plot on Age Group
fig = plt.figure(figsize = (15, 5))
sns.countplot(x ='LocationDesc', data = df_az)
plt.xticks(rotation=70)
 
# Show the plot
plt.show()

# %%
df_az_Gender=df_az[['Gender','Data_Value']].groupby('Gender').mean().reset_index()
df_az_Gender
# Out:
#     Gender  Data_Value
# 0   Female   36.976677
# 1     Male   34.970071
# 2  UnKnown   38.692571

# %%
fig = plt.figure(figsize = (15, 5))
sns.barplot(x ='Gender',y='Data_Value', data = df_az_Gender)
plt.xticks(rotation=70)
 
# Show the plot
plt.show()

# %%
df_az_location=df_az[['LocationDesc','Data_Value']].groupby('LocationDesc').mean().reset_index()

# %%
# count plot on Age Group
fig = plt.figure(figsize = (15, 5))
sns.barplot(x ='LocationDesc',y='Data_Value', data = df_az_location)
plt.xticks(rotation=70)
 
# Show the plot
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
label_encoder=LabelEncoder()

# %%
df_az.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Age_Group',
#        'Race_Ethnicity_Gender', 'Geolocation', 'ClassID', 'TopicID',
#        'QuestionID', 'LocationID', 'RowId', 'Race_Ethnicity', 'Gender'],
#       dtype='object')

# %%
df_az['LocationID']=label_encoder.fit_transform(df_az['LocationID'])
df_az['Class']=label_encoder.fit_transform(df_az['Class'])
df_az['Race_Ethnicity']=label_encoder.fit_transform(df_az['Race_Ethnicity'])
df_az['Gender']=label_encoder.fit_transform(df_az['Gender'])
df_az['Question']=label_encoder.fit_transform(df_az['Question'])
df_az['Topic']=label_encoder.fit_transform(df_az['Topic'])

# %%
featrues=['LocationID','Race_Ethnicity','Gender','Question','Topic']
target='Class'

# %%
x=df_az[featrues]
y=df_az[target]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model=RandomForestClassifier(n_estimators=100,random_state=42)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pr=rf_model.predict(x_test)

# %%
acc=accuracy_score(y_test,y_pr)
acc
# Out:
# 1.0
